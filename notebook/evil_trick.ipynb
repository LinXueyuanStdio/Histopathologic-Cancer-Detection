# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item"></ul></div>

# %%
import pandas as pd
import numpy as np  
from pathlib import Path  
import h5py
import hashlib
from tqdm import tqdm_notebook as tqdm

PATH = Path('.')
DATA_PATH = PATH/"../data/"

# %%
def create_pcam16_hash_table(dset_img):
    # creates a dictionary where each key is the sha-1 hash of the image data and the value is the index in the h5 file
    hash_table = {}
    for h5_id,img_id in enumerate(dset_img):
        hash_table[hashlib.sha1(img_id).hexdigest()] = h5_id
    return hash_table

def create_labels_dict(f):
    # creates a dictionary where each key is the img_id and the value is tumor or not
    df = pd.read_csv(f)
    labels_dict = {}
    for idx in range(len(df)):
        img_id = df.iloc[idx,0]
        is_tumor = df.iloc[idx,1]
        labels_dict[img_id] = int(is_tumor)
    return labels_dict

def create_wsi_dict(f):
    # creates a dictionary where each key is the h5 index and the value is the wsi
    df = pd.read_csv(f)
    
    dict_list = []
    for y,x,tp,ctp,wsi in zip(df.coord_y.tolist(), df.coord_x.tolist(), df.tumor_patch.tolist(), df.center_tumor_patch.tolist(), df.wsi.tolist()):
        dict_list.append({'coord_y':y,'coord_x':x, 'tumor_patch':tp,'center_tumor_patch':ctp,'wsi':wsi})
    wsi_dict = dict(zip(df.index.tolist(),dict_list))
    return wsi_dict

# %%
def postprocess(h5_file, labels_file, meta_file, name='new'):
    fimg = h5py.File(DATA_PATH/h5_file, 'r')

    hash_table = create_pcam16_hash_table(fimg['x'])
    labels_dict = create_labels_dict(DATA_PATH/labels_file)
    wsi_dict = create_wsi_dict(DATA_PATH/meta_file)

    ids = []
    label = []
    
    y = []
    x = []
    tp = []
    ctp = []
    wsi = []

    error_count = 0
    pbar = tqdm(labels_dict.items())
    for img_id, is_tumor in pbar:
        if img_id in hash_table.keys():
            h5_idx = hash_table[img_id]

            ids.append(img_id)
            label.append(is_tumor)

            y.append(wsi_dict[h5_idx]['coord_y'])
            x.append(wsi_dict[h5_idx]['coord_x'])
            tp.append(wsi_dict[h5_idx]['tumor_patch'])
            ctp.append(wsi_dict[h5_idx]['center_tumor_patch'])
            wsi_id = wsi_dict[h5_idx]['wsi']
            wsi.append(wsi_id)

            pbar.set_description("[ERROR:{}] h5:{}, wsi_id:{}, id:{}, is_tumor:{}".format(error_count, h5_idx, wsi_id, img_id, is_tumor))

        else:
            error_count = error_count+1
            pbar.set_description("[ERROR:{}] Image {} does not exist in external file".format(error_count, img_id))
            
    
    df_full_wsi = pd.DataFrame({'id':ids,'coord_y':y,'coord_x':x, 'tumor_patch':tp,'center_tumor_patch':ctp,'wsi':wsi,'is_tumor':label},columns=['id', 'coord_y', 'coord_x', 'tumor_patch', 'center_tumor_patch', 'wsi','is_tumor'])
    df_full_wsi.to_csv(DATA_PATH/labels_file.replace('.csv', '_wsi_{}.csv'.format(name)),index=False)
    
    print("Out of {} images, {} is unknown".format(len(pbar), error_count))

# %%
postprocess('camelyonpatch_level_2_split_valid_x.h5', "sample_submission.csv", 'camelyonpatch_level_2_split_valid_meta.csv', name='valid')
# Out:
# HBox(children=(IntProgress(value=0, max=57458), HTML(value='')))
# Out of 57458 images, 29350 is unknown

# %%
postprocess('camelyonpatch_level_2_split_test_x.h5', "sample_submission.csv", 'camelyonpatch_level_2_split_test_meta.csv', name='test')
# Out:
# HBox(children=(IntProgress(value=0, max=57458), HTML(value='')))
# Out of 57458 images, 28108 is unknown

# %%
origin = pd.read_csv(DATA_PATH/'hyp.csv').set_index('id')
origin_dict = origin.to_dict()

wsi_valid = pd.read_csv(DATA_PATH/'sample_submission_wsi_valid.csv').set_index('id')
wsi_valid_dict = wsi_valid.to_dict()

wsi_test = pd.read_csv(DATA_PATH/'sample_submission_wsi_test.csv').set_index('id')
wsi_test_dict = wsi_test.to_dict()

# %%
wsi_valid_dict
# Out:
# {'center_tumor_patch': {'db3278887b143632c75e5301608f3283607991e8': False,
#   '77656c206f3b8a1c1238332afbe43bf3ca09f6d1': False,
#   '2326bdb271a0e71f23b1b2c89df824e4df4be529': True,
#   'b2a303e1c3d82457ab15e997b3418f78fe7a43e1': False,
#   '1a9471385c773df28414453eca7d19e36b20df7d': True,
#   '23badba6556c0fb74d1757a2915b4da7895c05b1': True,
#   '1f3929e8256c2f385c1db4dbe9ee49b8ed161c61': True,
#   '9d9e87f1e9773004f5cfea84fc0cae7eb8b0d6d4': False,
#   '4fefce14b10451cdc84dc50d999bcc9f011d8aed': False,
#   '43a413819ec4bec526808a9c9f528c3cdb3a9e5b': False,
#   '9b919b2831501646e572e65eabc3235c0dcff287': False,
#   'b5451b3d2f6230d579fd0b5219f03f5778ee7cf7': False,
#   '526875c88144298578f95a12f1940d811c3cc23c': True,
#   'dd7fd9e0d8d419f052a73029fb4623f3f8f896c8': True,
#   '9d4b495eb7ed76a9455e08ea7ab35935007ebc80': True,
#   '42eb18db8373bd8c4e9ed1a9a2ac64d0251e56b3': True,
#   '0443737b84530547ec567c008ecf65ef0b4f216e': False,
#   '6dcd2f81e0bd16648e4ac65ab18dc892a99971d0': True,
#   'c0e8b7aac1982fdade46d5bc257c67a9d22f0ee0': False,
#   'de46fa2413c1e760bb11dacf6d12111dac21e629': False,
#   '196acec11c40c08aed281c207efb9622479b47aa': True,
#   '9ddefb641d51aa5e3f403772402819a88fa4f456': True,
#   '5e34e687b95a76ba0026c95f6c3c8e3a86735522': False,
#   '9dc9e0f3f8f5d10a453d867aa8f7e2dc34d267e2': True,
#   '4269a54f8936b53202b352649555dcb2e1860ff2': False,
#   '356e0b751df2a26d424fab52cc60b76feeb72dd5': False,
#   '0decb97d9b4217db4bf7f934c48b025bfdfa0d85': False,
#   'cd9d7b965f3ddc3ec39ff89bd13c39064f79007b': False,
#   'c3e1b585e625e1b0f76d481595f60889c9555526': True,
#   '44766bfec4d4e799168aa3e494b38fce79ca1c31': False,
#   '565ba01dfc0435eac1faea66957a0cf86aa50457': True,
#   '731cdd229f635776c283c1e474ed41dc3d2037af': False,
#   '322bf4533f9f860fe8b9adf92ec5251fe98bbf0b': False,
#   '369245a655fc63b95059657fd74b388d0e810b88': True,
#   'cf40c2171b8daa4f5f1af1258d0b2ed738b7b312': True,
#   '68cb84e6dae4ab2ec838cb805f60812bc2cf6cd5': True,
#   '92472c1d09fa0a23d798f5601692e96153996bcf': False,
#   'addc68bb431211a57dbe08dcd9a9bf233906aa12': False,
#   '1f49b10aac2eb4ed669f8c74078557bb7240c6e3': True,
#   'db415ab94a08adad4dfb102b05b1f32d2838eb41': False,
#   '1375a09bed707894c4d5be36243ee79f2433a69d': False,
#   'debab67be16b82f4708fd3b57c2c7e42702c53e7': False,
#   'a0b9caa8374b53eba58d834474e62544930d0591': False,
#   '5acc820f89d18362a2d06d981b5c23d607148f9d': False,
#   'c96bca5a6112189441a987137e209dcd95e00591': False,
#   '2b2b17e180fcb11c86887fe588149009d10b65ae': False,
#   'cd82a5aa41089821ba9a5ef5654e4a6cebabe108': True,
#   '5880f1be041cae246312228838dd7ac1f9d3171c': False,
#   'b113252c98e7bae037c2b4ec7f25038fb24a3bc1': True,
#   'c6e8812e63955a64cd05cbe70d9280557a184b38': False,
#   '6bca90e2d0053cb4b191750e99c402a65a120351': True,
#   '623b54f0a84daa964a2b7da07002d96e782820b1': True,
#   '270f1efb028e6b48ddcd41a900abf0284c839c00': True,
#   '9754395daf8b5cfafde80a217249f9d255851559': False,
#   '94d2c95b08d2a5747679587927563efb6764b811': True,
#   '2abfcc9e68793a2b0ae05db2736f4f8beed2b9f3': False,
#   '9df8f6aa326f27a90e75686dd08efa073e913f0a': False,
#   'e26d991af6600090f2a6e030d46a7e3d91fcd2a5': False,
#   'e31009409c9249194d4379091cce158b5e4b84d6': False,
#   'fee81b2130af43b4e62782b37905323d9035a669': False,
#   '7e0b33c567e207a590e7a84e0ea22fc31f1a577a': False,
#   '8872c975d8c9646ab402cb555c5cf5e1c9920d9c': True,
#   'f53da54ef51082c7c21f1071b07d846fb5bc3832': True,
#   'ae4f925d8ac2b97024f1dc55dd03a1d19e495ac0': True,
#   '34ce9b73e0c0f4d4d6bd53b805a6deb82e0699d9': False,
#   '3ab1c2f7a04c7d7c3c40d05cd58fb2bcf8bb53e1': False,
#   'd7160c32649a86f6adad8d82d888fec906b8c054': False,
#   '257204936d4f08e9a4afbaa900f58aae48369b53': False,
#   'aaf925ee7b04702e0e7b34009cfeab984b708913': True,
#   'b82d50413a682f058dcd808a2595306850c37713': False,
#   '2eeb80c799a77e17936514a4eb87238c2a506439': True,
#   '990aab09beb6866672dac872b505bb05f759cd2f': False,
#   '2b749cf6dbd6ff6ce747cb952f86c35b9005feca': False,
#   '7cabf608e2a2b59beefacbe67434f8fa93814943': False,
#   '8066f415145e2308da4aedbaf626f23d1c1f305e': False,
#   '3358650a7bca97fd4eaac7a7806c061307aa1c44': False,
#   '83bcb402cf8c9b46a92bc81431e3613c71d9f36d': False,
#   'd00ec2243c987388c8bf12eed3cf8a51201f27b1': True,
#   '9a133d03e9c2fd7d14d6c8fdbe183edaab5b2cb3': False,
#   'febc0f421e48c2a60cf86598e39d3d15e6f97345': False,
#   '8717368f47a65dfb007579a8dfce131ff9af0afc': False,
#   '583cc5d0b09869ca3d5e88c070cfa67d6f4a54c8': False,
#   'f0a385fb34f9d53e4b319a4956326ad0b9d50fd5': False,
#   'bfce3ffe164dc49e147742a28ea2d9913e92f9fc': True,
#   '1656b0fcfee43dd070bce9958172f86571d3d0a3': False,
#   'b76a9f2d7ec621fddf10baecd18dae6794db79fa': False,
#   '3e22ce243722f9f05fa084dd16385512b442e537': False,
#   '21c98c5a934a6fd7effd0265a951901dc1f3ddca': True,
#   'd09c17f6ff0673039d982c2c2aa2ae1ccdbd055d': False,
#   '1bd38227acb0f85ec438561c6d30649ba90803b8': True,
#   '6754d04cd3a3dc247e3e556b522c2ee67ae50ee6': False,
#   'bea7448ab79f28a7f74939a386a478e3b7efdcf2': False,
#   'd6135914f419ec84ca9f189c95ac4e8e9aa8874c': False,
#   '9100ae791c4d165c1a3d44b4c3e386222d76e169': False,
#   '7977bbf228c3e35249252bbc04cff527a44ecbbc': False,
#   'd23c66547f4a00555a174d2fcb860ae399b66edc': True,
#   'cfe332d88e830a42260303d024ee9c266092551c': False,
#   '16bd4df44820e2a405f774225c31ba5937145f17': False,
#   'c761ca360a74825c2755ecf4c7096d4807824eb7': True,
#   'bc30ffe4b5db7da2bb029dace256169ca93e5271': True,
#   'c76b5507521986a09db69c8b54587fb4a7cfd0aa': True,
#   'db1093edde211b1259c66535765048d59f746aa8': False,
#   '1c6c5c5f344d84e44931fa85f3f6933a3886437d': False,
#   'af8a47083560e52ddb3d930c42155536686deb04': True,
#   '7f2a9986a924964fde25b84d169292c9ed95a9ed': True,
#   '112c8c2cf458f5f102edae96838a515de488f953': True,
#   'e964b7953ecff96f0265c803c698f1af71b279f7': True,
#   'e9544ba58884a72262aee04c3dae05856ac4632f': True,
#   '5679f363edcba1bbec11d233fbfb73f0aa891add': False,
#   '09d54ca1c2514dd9b4f0e98b2cf3e6ed769f5e32': False,
#   '4f1cb880876cf4ea792c16cb89646741c94eda38': False,
#   'd933a5117608743c26bec503836689af8515f8bc': False,
#   '07693647a6c0050375fbf9b334046a642d8331e1': False,
#   'd5721f65d4219279e75d41f6f3ae3cb1089b355a': True,
#   'd5c858f75cccd0ee00d7acd2cc7aeed46f3dcf6c': False,
#   'f88d61f907c393e5a4a3697ccc6e4e92b27a2ad7': True,
#   'acdd71f6afc8fb5ed7d5ac0c056970fe989f2b88': False,
#   '6a861108e3832eca772d42d5eaa622525ddb31d5': False,
#   '2e14a0badf98d7ee7b0f04b3af93a9e7fc0b572e': False,
#   '10c9286a2fcbec15f64ee755e3090effcfcbccf1': True,
#   '02c5baba5f11ba797b50619094d1ec3a0864c73e': False,
#   '8a54eeb8212e7acfc9ffc13910809e4cf17ee706': True,
#   '5b10775bd98510ed1d0b240891c73056cc91eb17': False,
#   '1668234d40c0d6d2f7ab852bdfbab66916e2ecb2': False,
#   '5f2d31ec7f01841278a1040869f3df76817af57d': False,
#   '2f963d97e4ea70d43f96f2b84d46ed2320fae896': True,
#   '9224377dac3267bec4f82109c660659adb204b2e': False,
#   '142007f8e212f9d7d5eaee7f0bbfce07e947dc4f': False,
#   'bc5e38a9e4601118bff60b316321a14106281dcd': True,
#   '9cb29705abc4d1c860f775f1cbd189de6822b0cd': False,
#   'c2078f782c226b577745ccbaf0811bba86be758f': True,
#   'eaf9eac5b7c563a3e317077a139eb765d12c2579': True,
#   '57b7105c4f2c67574b7fedf768ad74ba44673b0c': False,
#   '92c809d1ddcfee86256fa6d6c4e4b82305248911': True,
#   'e65ffd5efec09849bbaaa7a0143357c0b9db508c': True,
#   'd9d5a5617b2696af117871921bea18021ac96281': False,
#   'afa10b4ba474fa48b2bef25b2fab3987d498d093': False,
#   'b4b3fac3ebb80e34dc437961e42d270895448c64': False,
#   'ce39faaf03a0642df3579d5176a08675c2363bc0': True,
#   '785e5a43f79da4a135f8be15008dd3ae806998f2': True,
#   'cbacad97c89791bee19491897f49205128ee3320': False,
#   'ad38a8162008763c2adcc8a9901bd0490f9fca9b': True,
#   'bf3502a6db3c923f62453cf9453bca26211027ec': True,
#   '0d3a5c4d5a8f28053b03443fec972ef022c903e4': False,
#   'b3461feea956f52019b4f33fa719931c9aafea49': True,
#   '98881c1f3ba984d722187f9d5e7b5bfc14d25d5b': False,
#   '90896d59c4ba5b41fa136785fa2037d44933a697': False,
#   'ca1628392d792ae25419c1249160480d7a51c011': False,
#   'e0d26f7277aee98da033ed6af7309a77628dd53c': True,
#   'cdc78fb7ba585ea0336b5d403ec881c423407c34': True,
#   '00d67b9b2de08f6c7e10e391c334d029f7f1251e': True,
#   'de83fa57679767419e1a7f5e04bd78a70a73f2a0': False,
#   '7e3ce4457f31f6ee21900bd438e60183b61eabb5': False,
#   '5c558052a0849aefbd214923b05091ebf9fc84ca': True,
#   '65be226cb5db2d51df8191bcd3e45870abbab062': False,
#   '5b05af9cf20018fea4586184152ccc72b7c146c7': False,
#   'd38784d9cade9e9f6f8e12395b1cf2cd41381f43': True,
#   '8b65b8ed41c1e48aceef1c7dfca57a5ee4df1ab2': False,
#   '13fd71ba076306c9574c03bd3ddb1d9e7f403436': False,
#   'b1fb93a368aaba9c5b01cb8adad362e34620b86e': True,
#   '552ccb4feb1dcc652246cd8c3cd009cbcf8c5ff7': False,
#   '5e31a944819a1a1d913bde8c69817be5a34698f5': True,
#   '8f8e1dd4045489b268648f796d11087e004682b1': False,
#   '4ae92119c76dfe1c93ebb57431281158f997fb90': False,
#   'bc0b420596419feeb71179e4a8a78f02a66436ca': True,
#   'ff7b3b291a8d32f5e2e847a02851171eddbe756c': True,
#   '50b40ccdd78437e558eb2a1771197d8a92090ca3': False,
#   '23f30124f2b1a5e270b61af17717a737e8a8c8b4': False,
#   '053586ac1f9636c6250f8b8ad446876ebee577c6': False,
#   '38843a260769e4cc0da016dc33f4d738386eab3d': True,
#   '148a3e491dbfbf53360235bb74b8ce17f41a3405': True,
#   '59517b383c5ed927eb3d41d5e1c2cf1565215d57': False,
#   'ea43b2a74c30684a70b632abfac91596dcdcda15': False,
#   'e418595ecbb8f0833cbd5c975af9f84b9ed535c0': False,
#   '060144b094106d7548631541737657cba93754e6': False,
#   'a70da0582d922e98cde9578176bcfcc8e53ff0b8': False,
#   '90027de6de7c52a4bc671cff3aee722d7b9e6f11': False,
#   '1acab075546a948e57e75bf8a18878a14a5ad2f5': False,
#   '1b48e52e2b239b908e60556f61c5b71b75ef67df': True,
#   'ff4311a611a8123fe0b023deeacfb5be9928ae27': True,
#   'fd59ed1fdb19372512719073e1ef25d58edf8bc7': True,
#   '5b5ae7bd8603861477f037f2e68474c8854283cd': False,
#   'c7feaabda98d28e2a7355ed8735dc35eab2a236e': True,
#   'e07ddd315e3037431689b18b3631c756a7220102': False,
#   '2cf721713746fad3da038035af81363cbc2ab94b': False,
#   'dcb651c7d7524c6032449e613b0f6a6dafacf386': False,
# ...
#   '71db68b8ef82e1bd97f02a466b86f0606145eacd': 'camelyon16_train_tumor_097',
#   'b4d6e44898ef7d6cf24ff47ddae82cf7ecece8e5': 'camelyon16_train_tumor_001',
#   '5fd6c0e500f9c8ddd5c1d3f972be0e3dae425f47': 'camelyon16_train_tumor_079',
#   'fc966d36af87bab6066b1dc0674d46172b0c0ae1': 'camelyon16_train_tumor_071',
#   '3cb3757344f304ac391e9273fe2b494d170243df': 'camelyon16_train_tumor_097',
#   'fce1cc6fb0cf0d252a263ae8cbb12ae25529dab4': 'camelyon16_train_normal_109',
#   'f5fda91f3589c0fc4f2c7a16d04c7c0badf2dd4b': 'camelyon16_train_normal_142',
#   'e3fe726d6c97f25a0e40bb47188ae65a97938ee1': 'camelyon16_train_tumor_001',
#   'cd4b6f17b8ab3b1e4e52f11878b10c8f5e868c89': 'camelyon16_train_tumor_011',
#   '2f5f4b2af903f8bf40398fb7d6efc566a08460ea': 'camelyon16_train_tumor_109',
#   '060147acbb9136679d16799848fc2d62d0d847b4': 'camelyon16_train_tumor_069',
#   '469bfeb93c0fa5cb4c875f3060f2822c8c931c54': 'camelyon16_train_tumor_082',
#   '6615a1e802c773b9e939cd2f24054a229932e53d': 'camelyon16_train_normal_143',
#   '29a8f3f1d6f55ac9e441051525e9172ee1be61cb': 'camelyon16_train_tumor_031',
#   '622ce98a8311debb4082e0c7f7b2322ea5140775': 'camelyon16_train_tumor_001',
#   'df9ac8874a3c2f1edeb087d7e9ab6c26c0d27286': 'camelyon16_train_tumor_097',
#   'f8afd4ba4d78483e6c4b2ed5cc7f37f499b70464': 'camelyon16_train_normal_057',
#   'f0a385fb34f9d53e4b319a4956326ad0b9d50fd5': 'camelyon16_train_normal_020',
#   'bfce3ffe164dc49e147742a28ea2d9913e92f9fc': 'camelyon16_train_tumor_082',
#   '1656b0fcfee43dd070bce9958172f86571d3d0a3': 'camelyon16_train_tumor_080',
#   'b76a9f2d7ec621fddf10baecd18dae6794db79fa': 'camelyon16_train_normal_143',
#   '3e22ce243722f9f05fa084dd16385512b442e537': 'camelyon16_train_normal_129',
#   '21c98c5a934a6fd7effd0265a951901dc1f3ddca': 'camelyon16_train_tumor_011',
#   'd09c17f6ff0673039d982c2c2aa2ae1ccdbd055d': 'camelyon16_train_normal_067',
#   '1bd38227acb0f85ec438561c6d30649ba90803b8': 'camelyon16_train_tumor_031',
#   '6754d04cd3a3dc247e3e556b522c2ee67ae50ee6': 'camelyon16_train_normal_099',
#   'bea7448ab79f28a7f74939a386a478e3b7efdcf2': 'camelyon16_train_normal_099',
#   'd6135914f419ec84ca9f189c95ac4e8e9aa8874c': 'camelyon16_train_tumor_012',
#   '9100ae791c4d165c1a3d44b4c3e386222d76e169': 'camelyon16_train_normal_032',
#   '7977bbf228c3e35249252bbc04cff527a44ecbbc': 'camelyon16_train_tumor_065',
#   'd23c66547f4a00555a174d2fcb860ae399b66edc': 'camelyon16_train_tumor_079',
#   'cfe332d88e830a42260303d024ee9c266092551c': 'camelyon16_train_tumor_043',
#   '16bd4df44820e2a405f774225c31ba5937145f17': 'camelyon16_train_normal_143',
#   'c761ca360a74825c2755ecf4c7096d4807824eb7': 'camelyon16_train_tumor_005',
#   'bc30ffe4b5db7da2bb029dace256169ca93e5271': 'camelyon16_train_tumor_031',
#   'c76b5507521986a09db69c8b54587fb4a7cfd0aa': 'camelyon16_train_tumor_082',
#   'db1093edde211b1259c66535765048d59f746aa8': 'camelyon16_train_tumor_081',
#   '1c6c5c5f344d84e44931fa85f3f6933a3886437d': 'camelyon16_train_normal_013',
#   'af8a47083560e52ddb3d930c42155536686deb04': 'camelyon16_train_tumor_082',
#   '7f2a9986a924964fde25b84d169292c9ed95a9ed': 'camelyon16_train_tumor_071',
#   '112c8c2cf458f5f102edae96838a515de488f953': 'camelyon16_train_tumor_069',
#   'e964b7953ecff96f0265c803c698f1af71b279f7': 'camelyon16_train_tumor_065',
#   'e9544ba58884a72262aee04c3dae05856ac4632f': 'camelyon16_train_tumor_071',
#   '5679f363edcba1bbec11d233fbfb73f0aa891add': 'camelyon16_train_tumor_013',
#   '09d54ca1c2514dd9b4f0e98b2cf3e6ed769f5e32': 'camelyon16_train_normal_019',
#   '4f1cb880876cf4ea792c16cb89646741c94eda38': 'camelyon16_train_normal_052',
#   'd933a5117608743c26bec503836689af8515f8bc': 'camelyon16_train_normal_013',
#   '07693647a6c0050375fbf9b334046a642d8331e1': 'camelyon16_train_normal_030',
#   'd5721f65d4219279e75d41f6f3ae3cb1089b355a': 'camelyon16_train_tumor_079',
#   'd5c858f75cccd0ee00d7acd2cc7aeed46f3dcf6c': 'camelyon16_train_tumor_013',
#   'f88d61f907c393e5a4a3697ccc6e4e92b27a2ad7': 'camelyon16_train_tumor_082',
#   'acdd71f6afc8fb5ed7d5ac0c056970fe989f2b88': 'camelyon16_train_tumor_082',
#   '6a861108e3832eca772d42d5eaa622525ddb31d5': 'camelyon16_train_normal_109',
#   '2e14a0badf98d7ee7b0f04b3af93a9e7fc0b572e': 'camelyon16_train_normal_148',
#   '10c9286a2fcbec15f64ee755e3090effcfcbccf1': 'camelyon16_train_tumor_080',
#   '02c5baba5f11ba797b50619094d1ec3a0864c73e': 'camelyon16_train_normal_031',
#   '8a54eeb8212e7acfc9ffc13910809e4cf17ee706': 'camelyon16_train_tumor_046',
#   '5b10775bd98510ed1d0b240891c73056cc91eb17': 'camelyon16_train_normal_148',
#   '1668234d40c0d6d2f7ab852bdfbab66916e2ecb2': 'camelyon16_train_tumor_069',
#   '5f2d31ec7f01841278a1040869f3df76817af57d': 'camelyon16_train_tumor_097',
#   '2f963d97e4ea70d43f96f2b84d46ed2320fae896': 'camelyon16_train_tumor_046',
#   '9224377dac3267bec4f82109c660659adb204b2e': 'camelyon16_train_normal_102',
#   '142007f8e212f9d7d5eaee7f0bbfce07e947dc4f': 'camelyon16_train_normal_095',
#   'bc5e38a9e4601118bff60b316321a14106281dcd': 'camelyon16_train_tumor_080',
#   '9cb29705abc4d1c860f775f1cbd189de6822b0cd': 'camelyon16_train_normal_076',
#   'c2078f782c226b577745ccbaf0811bba86be758f': 'camelyon16_train_tumor_069',
#   'eaf9eac5b7c563a3e317077a139eb765d12c2579': 'camelyon16_train_tumor_069',
#   '57b7105c4f2c67574b7fedf768ad74ba44673b0c': 'camelyon16_train_normal_079',
#   '92c809d1ddcfee86256fa6d6c4e4b82305248911': 'camelyon16_train_tumor_046',
#   'e65ffd5efec09849bbaaa7a0143357c0b9db508c': 'camelyon16_train_tumor_082',
#   'd9d5a5617b2696af117871921bea18021ac96281': 'camelyon16_train_normal_013',
#   'afa10b4ba474fa48b2bef25b2fab3987d498d093': 'camelyon16_train_normal_067',
#   'b4b3fac3ebb80e34dc437961e42d270895448c64': 'camelyon16_train_tumor_043',
#   'ce39faaf03a0642df3579d5176a08675c2363bc0': 'camelyon16_train_tumor_085',
#   '785e5a43f79da4a135f8be15008dd3ae806998f2': 'camelyon16_train_tumor_005',
#   'cbacad97c89791bee19491897f49205128ee3320': 'camelyon16_train_normal_067',
#   'ad38a8162008763c2adcc8a9901bd0490f9fca9b': 'camelyon16_train_tumor_057',
#   'bf3502a6db3c923f62453cf9453bca26211027ec': 'camelyon16_train_tumor_001',
#   '0d3a5c4d5a8f28053b03443fec972ef022c903e4': 'camelyon16_train_normal_031',
#   'b3461feea956f52019b4f33fa719931c9aafea49': 'camelyon16_train_tumor_069',
#   '98881c1f3ba984d722187f9d5e7b5bfc14d25d5b': 'camelyon16_train_tumor_012',
#   '90896d59c4ba5b41fa136785fa2037d44933a697': 'camelyon16_train_normal_098',
#   'ca1628392d792ae25419c1249160480d7a51c011': 'camelyon16_train_normal_030',
#   'e0d26f7277aee98da033ed6af7309a77628dd53c': 'camelyon16_train_tumor_046',
#   'cdc78fb7ba585ea0336b5d403ec881c423407c34': 'camelyon16_train_tumor_019',
#   '00d67b9b2de08f6c7e10e391c334d029f7f1251e': 'camelyon16_train_tumor_001',
#   'de83fa57679767419e1a7f5e04bd78a70a73f2a0': 'camelyon16_train_normal_017',
#   '7e3ce4457f31f6ee21900bd438e60183b61eabb5': 'camelyon16_train_normal_109',
#   '5c558052a0849aefbd214923b05091ebf9fc84ca': 'camelyon16_train_tumor_013',
#   '65be226cb5db2d51df8191bcd3e45870abbab062': 'camelyon16_train_normal_020',
#   '5b05af9cf20018fea4586184152ccc72b7c146c7': 'camelyon16_train_tumor_012',
#   'd38784d9cade9e9f6f8e12395b1cf2cd41381f43': 'camelyon16_train_tumor_037',
#   '8b65b8ed41c1e48aceef1c7dfca57a5ee4df1ab2': 'camelyon16_train_tumor_097',
#   '13fd71ba076306c9574c03bd3ddb1d9e7f403436': 'camelyon16_train_normal_030',
#   'b1fb93a368aaba9c5b01cb8adad362e34620b86e': 'camelyon16_train_tumor_057',
#   '552ccb4feb1dcc652246cd8c3cd009cbcf8c5ff7': 'camelyon16_train_tumor_013',
#   '5e31a944819a1a1d913bde8c69817be5a34698f5': 'camelyon16_train_tumor_037',
#   '8f8e1dd4045489b268648f796d11087e004682b1': 'camelyon16_train_normal_031',
#   '4ae92119c76dfe1c93ebb57431281158f997fb90': 'camelyon16_train_normal_132',
#   'bc0b420596419feeb71179e4a8a78f02a66436ca': 'camelyon16_train_tumor_079',
#   'ff7b3b291a8d32f5e2e847a02851171eddbe756c': 'camelyon16_train_tumor_043',
#   '50b40ccdd78437e558eb2a1771197d8a92090ca3': 'camelyon16_train_tumor_037',
#   '23f30124f2b1a5e270b61af17717a737e8a8c8b4': 'camelyon16_train_normal_057',
#   '053586ac1f9636c6250f8b8ad446876ebee577c6': 'camelyon16_train_normal_105',
#   '38843a260769e4cc0da016dc33f4d738386eab3d': 'camelyon16_train_tumor_097',
#   '148a3e491dbfbf53360235bb74b8ce17f41a3405': 'camelyon16_train_tumor_001',
#   '59517b383c5ed927eb3d41d5e1c2cf1565215d57': 'camelyon16_train_tumor_012',
#   'ea43b2a74c30684a70b632abfac91596dcdcda15': 'camelyon16_train_normal_031',
#   'e418595ecbb8f0833cbd5c975af9f84b9ed535c0': 'camelyon16_train_tumor_001',
#   '060144b094106d7548631541737657cba93754e6': 'camelyon16_train_normal_056',
#   'a70da0582d922e98cde9578176bcfcc8e53ff0b8': 'camelyon16_train_tumor_080',
#   '90027de6de7c52a4bc671cff3aee722d7b9e6f11': 'camelyon16_train_normal_142',
#   '1acab075546a948e57e75bf8a18878a14a5ad2f5': 'camelyon16_train_normal_013',
#   '1b48e52e2b239b908e60556f61c5b71b75ef67df': 'camelyon16_train_tumor_001',
#   'ff4311a611a8123fe0b023deeacfb5be9928ae27': 'camelyon16_train_tumor_037',
#   'fd59ed1fdb19372512719073e1ef25d58edf8bc7': 'camelyon16_train_tumor_046',
#   '5b5ae7bd8603861477f037f2e68474c8854283cd': 'camelyon16_train_normal_152',
#   'c7feaabda98d28e2a7355ed8735dc35eab2a236e': 'camelyon16_train_tumor_082',
#   'e07ddd315e3037431689b18b3631c756a7220102': 'camelyon16_train_tumor_069',
#   '2cf721713746fad3da038035af81363cbc2ab94b': 'camelyon16_train_normal_076',
#   'dcb651c7d7524c6032449e613b0f6a6dafacf386': 'camelyon16_train_normal_079',
#   '4da51545b7cdf8a24a0448d7c49182f40d01bdb3': 'camelyon16_train_tumor_013',
#   '46ac146642e844dc138169ef9db436099670ff54': 'camelyon16_train_normal_013',
#   '862bc61e7052ef8e5a7fe57dd976333aeb606ca4': 'camelyon16_train_normal_019',
#   'f4baee8059182bc292b7593c936afb60ac4f1182': 'camelyon16_train_tumor_071',
#   'ebfeab0ebe616566f708108f88b29b1fc8b82376': 'camelyon16_train_tumor_097',
#   '7101d21a3555d5b15c5685a41c8e77eada7fec62': 'camelyon16_train_tumor_037',
#   '91ad5343b4462b36ee5b7ba2935d958ff399f6c3': 'camelyon16_train_tumor_069',
#   'a6cf3095ac5dc21032ad138d9224f9144ca99c73': 'camelyon16_train_tumor_046',
#   '16775e17aa41e2f7b632969b2b8d206eb0c073b5': 'camelyon16_train_tumor_073',
#   '005e75e90911d428f4b01af9565ad1f1715a8c3e': 'camelyon16_train_tumor_073',
#   '22965ee90977cea5a9fc45d5eb00c90b64b17f10': 'camelyon16_train_tumor_012',
#   '1d4ed4e58300d774c6416ff3c93fe95f062600c8': 'camelyon16_train_normal_019',
#   'b66df8933887be9005baae431dbe15c1575cf867': 'camelyon16_train_normal_129',
#   '4c5f6b96d06fab13c051507728c75e8cd44b557f': 'camelyon16_train_normal_105',
#   '8ce88a75960a6dbac5fac99257d5045dd860712f': 'camelyon16_train_tumor_005',
#   '26efe81ccfff6018fbbfb1c517bd79cf92a566f4': 'camelyon16_train_tumor_082',
#   'd695210c5c246acaddfa2523dff65d1118963143': 'camelyon16_train_normal_137',
#   '829912f1ece888bee02c00b40bd3b837b989e7b4': 'camelyon16_train_tumor_013',
#   '92e3066a0ceb01218a626f3bb3e68ae7bc721dc0': 'camelyon16_train_tumor_012',
#   '0990506dfbc7d77ad08751645db1012f74ee960f': 'camelyon16_train_normal_109',
#   '9dea60903fe1f9cfc3e60d04a3024322d6ad91f0': 'camelyon16_train_tumor_031',
#   'cd5cc4ddeb640006ceafa4bddbe0be6700930ef7': 'camelyon16_train_tumor_043',
#   '0a29a7f1b19d7fdc64ca3695deda6ff28a1b3531': 'camelyon16_train_normal_132',
#   '01f13fa6148d4d4f1e2424774a1746dfe586b38e': 'camelyon16_train_tumor_081',
#   '4d8e8b77e23f6e2cc1a8a6ef0e7d9c1563f5adce': 'camelyon16_train_normal_025',
#   '997b162f367a71a690d3e804ccb1a621b5163510': 'camelyon16_train_tumor_065',
#   '6f558481ca5e8ca7ea8038c5f9d88ecc66ce9835': 'camelyon16_train_tumor_069',
#   '50258618d2c1bca4a22d5cf07028591a432fabce': 'camelyon16_train_tumor_079',
#   '59f8a1250bc43e13c18a5ffc604c80062eee4f00': 'camelyon16_train_tumor_073',
#   'e8f6406feffce32c81cc2f4ba0477063aa63e0ee': 'camelyon16_train_tumor_001',
#   '4a06801d9b0ab9ac3386710435410162a77e6b86': 'camelyon16_train_tumor_079',
#   '1f2b6eecbc3250fbecd5b8bfaffa69b8a5d11e05': 'camelyon16_train_tumor_012',
#   '966a2a1724ebea1412b94f28218a65230c55422f': 'camelyon16_train_tumor_080',
#   'f03e7a7fb2bba65553f07a4345c34ace21cb793b': 'camelyon16_train_normal_099',
#   '3f2d52f5094cc679a4e89f8348ce5a233ca25e8b': 'camelyon16_train_tumor_001',
#   '9c8175b7369bc565ee226a56ec5aac637f4d1b39': 'camelyon16_train_tumor_082',
#   '441114a4cd311063f8a86775c903d9705ee95ef2': 'camelyon16_train_normal_095',
#   '364b6d57623afc7fcc377b11b5bb4e0c9bdcd898': 'camelyon16_train_tumor_080',
#   'bb1840155b9251baa813ad85ed6348d3916a003d': 'camelyon16_train_tumor_057',
#   '7b05046b39facda1fd47199f7d3529a8a6ae3cef': 'camelyon16_train_tumor_080',
#   'cca7d9ea998dd19f4e8a299269f7c49e91379382': 'camelyon16_train_normal_025',
#   '333a39e0259956a91ca6679478f5bbeba36a7b68': 'camelyon16_train_normal_017',
#   '1568575fbf58300ed259482bddac3baa9e9e9ddc': 'camelyon16_train_normal_129',
#   '096e114cf7e673cfba3a7d00604bdaaed7d01504': 'camelyon16_train_tumor_031',
#   '6c48d00051ffc4948bc61276a337bdb860a8b857': 'camelyon16_train_tumor_097',
#   'ff40a8b50ebd27e4b8c2de1be49845a3e77eaa75': 'camelyon16_train_normal_030',
#   'f8e7a8026a7f3b13969e1684e2e4d89badafc075': 'camelyon16_train_tumor_080',
#   '5499bce72d29c7d259066067e8717036e2ce1b9c': 'camelyon16_train_normal_152',
#   '21df32121d950548c5f4651495d473fb41c19fc7': 'camelyon16_train_tumor_043',
#   '5c0a54e07e5121d32dacdbe680adfb3d16a169d0': 'camelyon16_train_normal_032',
#   '20480f544c1292238865c4f901887bd043c5dc10': 'camelyon16_train_tumor_037',
#   '8164d07b6be0c2c4cfea8751f187bf70a95cf30f': 'camelyon16_train_tumor_005',
#   '51a9e1f4868a27e4cc60ce40f2ada24930667d0b': 'camelyon16_train_normal_129',
#   '5056f2ea4b04de90550ee1358a01b216553b2c64': 'camelyon16_train_tumor_097',
#   '6445ea62e94d5e1a2507df5d675eaed930a4f4ee': 'camelyon16_train_tumor_001',
#   'bbebd5199c16ac534bc9350c407aa91fa760d950': 'camelyon16_train_normal_017',
#   '8d606edc9503bb8f5841cf84b643de802dfcc54b': 'camelyon16_train_tumor_069',
#   'd22346939a5a131f99540871dfbd2f81490b45f6': 'camelyon16_train_normal_031',
#   '46f1bcac95ed1bd168b330996ca17851598eb3ae': 'camelyon16_train_normal_056',
#   '3de3cb5f75980a93c302b35d4d17d98021e38327': 'camelyon16_train_normal_152',
#   '32a507148296272aa764b0737d851c12c0545941': 'camelyon16_train_normal_098',
#   '1e0dbb40a9953416f2fe58d1142a82ab515f6c51': 'camelyon16_train_tumor_082',
#   '3ca1e2de90b0cde8b4f885eaa7ee33a955f8be94': 'camelyon16_train_tumor_012',
#   '4ce61e3d82a730b680184cb5923d39332ccfbeaa': 'camelyon16_train_tumor_069',
#   '356dcff59c1fe31473a1efd6dc03a918b73b6157': 'camelyon16_train_tumor_071',
#   '1c9f31e480e4e89f08244b49e54478a85111cbd1': 'camelyon16_train_tumor_019',
#   '1ca836b443ae1a54b76f780b565fc2e87255b907': 'camelyon16_train_normal_132',
#   '035eab2084cd585734af609284238ddcd64bc93d': 'camelyon16_train_normal_102',
#   '32caca80c3b89fc5f8d9e5d62fc74ba55e3963ec': 'camelyon16_train_tumor_012',
#   'e5afc5dcc391f943ba022a43a044af2c3720054e': 'camelyon16_train_tumor_046',
#   'cff05d7359b4f75e36cf4cd14cbe0c6c74f9ad62': 'camelyon16_train_tumor_005',
#   '3d0c0a8e40006141f7985cd81c5d37085fa0f49a': 'camelyon16_train_tumor_097',
#   '16751af3521600dc28e06b33003f056a1a2bcc1a': 'camelyon16_train_normal_085',
#   '02cfb7f393c95d5a1ecba6776ec5392e21e1a8a7': 'camelyon16_train_normal_098',
#   '0369faeaaed451d73331f393e6090298ad1bd6b5': 'camelyon16_train_tumor_011',
#   '150f6d873a88f737a56a498625d22151cde78e33': 'camelyon16_train_normal_076',
#   '57509982f609cff21820884c1bc7463d50578609': 'camelyon16_train_tumor_069',
#   '9a0f42ba26c4f81bf8cc55b4081010d5ca4f3be2': 'camelyon16_train_tumor_001',
#   '5b16fc5008289a6abb416fd0fe06602845e00ccd': 'camelyon16_train_normal_010',
#   '03b30c0e4eb807d3d7781f9261f89271c35b1fd3': 'camelyon16_train_tumor_057',
#   '2958368c64e90927a54464d09779997516b82e6b': 'camelyon16_train_normal_143',
#   '1cfc2cbeb2ee58bf160741f6fb00e5a0f0bf9460': 'camelyon16_train_tumor_080',
#   '005a7ca6538a653113dc8878e5a94fb823496498': 'camelyon16_train_tumor_071',
#   'b73d47f564ec4327980d64616dc2ee319a8ad59f': 'camelyon16_train_tumor_069',
#   '6aefc1550d171fbd95638d0fd3b88843e9a733ff': 'camelyon16_train_tumor_011',
#   '905efc3c52362072eb9e9b242fa46c6d3e66e75b': 'camelyon16_train_normal_085',
#   'f85719a6165cb2d7cc5832417f1ca95d996b933c': 'camelyon16_train_tumor_071',
#   'c40ce4d0e4788bf9f0cc0bbecdf14744d21a702d': 'camelyon16_train_normal_129',
#   ...}}

# %%
pbar = tqdm(origin_dict['label'].keys())

img_id_new = []
label_new = []

error_count = 0
for img_id in pbar:
    if img_id in wsi_valid_dict['tumor_patch'].keys():
        if wsi_valid_dict['tumor_patch'][img_id] == False:
            img_id_new.append(img_id)
            label_new.append(0.)
            pbar.set_description("[ERROR={}] {} = 0".format(error_count, img_id))
        else:
            img_id_new.append(img_id)
            label_new.append(origin_dict['label'][img_id])
    else:
        img_id_new.append(img_id)
        label_new.append(origin_dict['label'][img_id])
        error_count = error_count+1
        pbar.set_description("[ERROR={}] No id found.".format(error_count))

out = pd.DataFrame({'id': img_id_new, 'label': label_new}, columns=['id', 'label'])
out.to_csv(DATA_PATH/'output.csv',index=False)
# Out:
# HBox(children=(IntProgress(value=0, max=57458), HTML(value='')))

# %%
pbar = tqdm(origin_dict['label'].keys())

img_id_new = []
label_new = []

error_count = 0
for img_id in pbar:
    if img_id in wsi_test_dict['tumor_patch'].keys():
        if wsi_test_dict['tumor_patch'][img_id] == False:
            img_id_new.append(img_id)
            label_new.append(0.)
            pbar.set_description("[ERROR={}] {} = 0".format(error_count, img_id))
        else:
            img_id_new.append(img_id)
            label_new.append(origin_dict['label'][img_id])
    else:
        img_id_new.append(img_id)
        label_new.append(origin_dict['label'][img_id])
        error_count = error_count+1
        pbar.set_description("[ERROR={}] No id found.".format(error_count))

out = pd.DataFrame({'id': img_id_new, 'label': label_new}, columns=['id', 'label'])
out.to_csv(DATA_PATH/'output.csv',index=False)
# Out:
# HBox(children=(IntProgress(value=0, max=57458), HTML(value='')))

# %%
pbar = tqdm(origin_dict['label'].keys())

img_id_new = []
label_new = []

error_count = 0
for img_id in pbar:
    if img_id in wsi_test_dict['tumor_patch'].keys():
        if wsi_test_dict['center_tumor_patch'][img_id] == False:
            img_id_new.append(img_id)
            label_new.append(1)
            pbar.set_description("[ERROR={}] {} = 0".format(error_count, img_id))
        elif wsi_test_dict['center_tumor_patch'][img_id] == True:
            img_id_new.append(img_id)
            label_new.append(0)
            pbar.set_description("[ERROR={}] {} = 0".format(error_count, img_id))
        else:
            img_id_new.append(img_id)
            label_new.append(origin_dict['label'][img_id])
            error_count = error_count+1
    elif img_id in wsi_valid_dict['tumor_patch'].keys():
        if wsi_valid_dict['center_tumor_patch'][img_id] == False:
            img_id_new.append(img_id)
            label_new.append(0)
            pbar.set_description("[ERROR={}] {} = 0".format(error_count, img_id))
        elif wsi_valid_dict['center_tumor_patch'][img_id] == True:
            img_id_new.append(img_id)
            label_new.append(1)
            pbar.set_description("[ERROR={}] {} = 0".format(error_count, img_id))
        else:
            img_id_new.append(img_id)
            label_new.append(origin_dict['label'][img_id])
            error_count = error_count+1
    else:
        img_id_new.append(img_id)
        label_new.append(origin_dict['label'][img_id])
        error_count = error_count+1
        pbar.set_description("[ERROR={}] No id found.".format(error_count))

out = pd.DataFrame({'id': img_id_new, 'label': label_new}, columns=['id', 'label'])
out.to_csv(DATA_PATH/'output.csv',index=False)
# Out:
# HBox(children=(IntProgress(value=0, max=57458), HTML(value='')))
